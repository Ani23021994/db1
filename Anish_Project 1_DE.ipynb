# %%
# %sql
create catalog if not exists projectAnish001
managed location 'abfss://project1@dbproject.dfs.core.windows.net/'  /*blob container name*/
comment 'creating first catalog'

# %%
# %fs ls abfss://project1@dbproject.dfs.core.windows.net/
